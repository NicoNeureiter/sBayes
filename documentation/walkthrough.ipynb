# %%
from sbayes.experiment_setup import Experiment
from sbayes.load_data import Data
from sbayes.mcmc_setup import MCMCSetup

# %%
# Initialize the experiment
experiment = Experiment(
    config_file="../experiments/south_america/config.yaml",
    experiment_name="playground",
)

# Load the data
data = Data.from_experiment(experiment)

# Set up MCMC
mcmc = MCMCSetup(data, experiment)
mcmc.sample(resume=False)
# Out:
# /Users/nneureiter/Projects/sBayes/sbayes/config/config.py:640: UserWarning: The `feature_states` field is deprecated. Please use `feature_types` instead.
#   warnings.warn("The `feature_states` field is deprecated. Please use `feature_types` instead.")
# /Users/nneureiter/Projects/sBayes/sbayes/config/config.py:298: UserWarning: No `type` defined for `ClusterEffectConfig`. Using `uniform` as a default.
#   warnings.warn(
# Experiment: playground
# File location for results: /Users/nneureiter/Projects/sBayes/experiments/south_america/results/playground
# Start time and date: 15:32:10 14.07.2025
#
#
# DATA IMPORT
# ##########################################
# 100 objects with 36 features read from /Users/nneureiter/Projects/sBayes/experiments/south_america/data/features.csv.
# Categorical[2]: 30 feature(s) with 77 NA value(s).
# Categorical[5]: 2 feature(s) with 1 NA value(s).
# Categorical[4]: 3 feature(s) with 11 NA value(s).
# Categorical[3]: 1 feature(s) with 3 NA value(s).
# ...
